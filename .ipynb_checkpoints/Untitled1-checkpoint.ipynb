# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_train = np.linspace(-20, 20, 401).reshape([1,-1])
y_train = 400 * np.sin(x_train) + 100*np.random.randn(1,401) + 2*x_train*x_train
font = {'family':'normal',
       'weight':'bold',
       'size':20}
plt.rc('font', **font)
plt.figure(figsize=(20,15))
plt.plot(x_train[0], y_train[0])
x_train.shap
# Out:
# (1, 401)
# /home/suzi/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
x = tf.placeholder(tf.float32, [1, 401])
def weight(shape):
    return tf.Variable(tf.truncated_normal(shape, stddv=0.1))
def bias(shape):
    return tf.Variable(tf.constant(0.1, shape=shape))

# %%
w1 = weight([401, 64])
b1 = bias(401)
